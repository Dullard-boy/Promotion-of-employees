# %%
import pandas as pd

# %%
sample=pd.read_csv('C:/Users/hp/Desktop/Python Courses/Employee project/sample_submission.csv')
sample
# Out:
#        employee_id  is_promoted
# 0             8724            0
# 1            74430            0
# 2            72255            0
# 3            38562            0
# 4            64486            0
# ...            ...          ...
# 23485        53478            0
# 23486        25600            0
# 23487        45409            0
# 23488         1186            0
# 23489         5973            0
#
# [23490 rows x 2 columns]

# %%
sample['is_promoted'].value_counts()
# Out:
# 0    23490
# Name: is_promoted, dtype: int64

# %%
train=pd.read_csv('C:/Users/hp/Desktop/Python Courses/Employee project/train.csv')
train
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
train['department'].value_counts()
# Out:
# Sales & Marketing    16840
# Operations           11348
# Procurement           7138
# Technology            7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: department, dtype: int64

# %%
grouped=train.groupby('department')
for name, group in grouped:
    print(name)
    group['education'].fillna('Unknown')
    print('Education Statistics')
    print(group['education'].value_counts())
    print('')
# Out:
# Analytics
# Education Statistics
# Bachelor's          3978
# Master's & above    1037
# Name: education, dtype: int64
#
# Finance
# Education Statistics
# Bachelor's          1895
# Master's & above     499
# Below Secondary      106
# Name: education, dtype: int64
#
# HR
# Education Statistics
# Bachelor's          1525
# Master's & above     733
# Below Secondary      128
# Name: education, dtype: int64
#
# Legal
# Education Statistics
# Bachelor's          814
# Master's & above    156
# Below Secondary      65
# Name: education, dtype: int64
#
# Operations
# Education Statistics
# Bachelor's          7781
# Master's & above    3165
# Below Secondary      176
# Name: education, dtype: int64
#
# Procurement
# Education Statistics
# Bachelor's          4393
# Master's & above    2544
# Below Secondary      129
# Name: education, dtype: int64
#
# R&D
# Education Statistics
# Bachelor's          542
# Master's & above    429
# Name: education, dtype: int64
#
# Sales & Marketing
# ...

# %%
grouped=train.groupby('department')
for name, group in grouped:
    print(name)
    print('Gender Statistics')
    print(group['gender'].value_counts())
    print('')
# Out:
# Analytics
# Gender Statistics
# m    4839
# f     513
# Name: gender, dtype: int64
#
# Finance
# Gender Statistics
# m    1855
# f     681
# Name: gender, dtype: int64
#
# HR
# Gender Statistics
# m    1412
# f    1006
# Name: gender, dtype: int64
#
# Legal
# Gender Statistics
# m    890
# f    149
# Name: gender, dtype: int64
#
# Operations
# Gender Statistics
# m    6671
# f    4677
# Name: gender, dtype: int64
#
# Procurement
# Gender Statistics
# m    3851
# f    3287
# Name: gender, dtype: int64
#
# R&D
# Gender Statistics
# m    942
# f     57
# Name: gender, dtype: int64
#
# Sales & Marketing
# Gender Statistics
# m    13686
# f     3154
# Name: gender, dtype: int64
#
# Technology
# Gender Statistics
# m    4350
# f    2788
# Name: gender, dtype: int64

# %%
grouped=train.groupby('department')
for name, group in grouped:
    print(name)
    print('Recruitment Statistics')
    print(group['recruitment_channel'].value_counts())
    print('')
# Out:
# Analytics
# Recruitment Statistics
# other       2973
# sourcing    2296
# referred      83
# Name: recruitment_channel, dtype: int64
#
# Finance
# Recruitment Statistics
# other       1463
# sourcing    1068
# referred       5
# Name: recruitment_channel, dtype: int64
#
# HR
# Recruitment Statistics
# other       1380
# sourcing     935
# referred     103
# Name: recruitment_channel, dtype: int64
#
# Legal
# Recruitment Statistics
# other       590
# sourcing    435
# referred     14
# Name: recruitment_channel, dtype: int64
#
# Operations
# Recruitment Statistics
# other       6279
# sourcing    4831
# referred     238
# Name: recruitment_channel, dtype: int64
#
# Procurement
# Recruitment Statistics
# other       4002
# sourcing    3057
# referred      79
# Name: recruitment_channel, dtype: int64
#
# R&D
# Recruitment Statistics
# other       555
# sourcing    425
# referred     19
# Name: recruitment_channel, dtype: int64
#
# Sales & Marketing
# Recruitment Statistics
# ...

# %%
train['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
train['previous_year_rating'].mean()
# Out:
# 3.329255780917055

# %%
train['previous_year_rating'].fillna(train['previous_year_rating'].mean(), inplace=True)
pd.cut(train['previous_year_rating'], bins=['0.0','2.9','5.0'], labels=['0','1'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 54803    1
# 54804    0
# 54805    1
# 54806    0
# 54807    0
# Name: previous_year_rating, Length: 54808, dtype: category
# Categories (2, object): ['0' < '1']

# %%
pd.cut(train['avg_training_score'], bins=['0','59','99'], labels=['0','1'])
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 54803    1
# 54804    0
# 54805    1
# 54806    0
# 54807    0
# Name: avg_training_score, Length: 54808, dtype: category
# Categories (2, object): ['0' < '1']

# %%
data1=pd.DataFrame(pd.cut(train['avg_training_score'], bins=['0','59','99'], labels=['0','1']))
data1
# Out:
#       avg_training_score
# 0                      0
# 1                      1
# 2                      0
# 3                      0
# 4                      1
# ...                  ...
# 54803                  1
# 54804                  0
# 54805                  1
# 54806                  0
# 54807                  0
#
# [54808 rows x 1 columns]

# %%
train.update(data1, overwrite=True)
train
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
data2=pd.DataFrame(pd.cut(train['previous_year_rating'], bins=['0.0','2.9','5.0'], labels=['0','1']))
data2
# Out:
#       previous_year_rating
# 0                        1
# 1                        1
# 2                        1
# 3                        0
# 4                        1
# ...                    ...
# 54803                    1
# 54804                    0
# 54805                    1
# 54806                    0
# 54807                    0
#
# [54808 rows x 1 columns]

# %%
train.update(data2, overwrite=True)
train
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
train['awards_won?'].value_counts()
# Out:
# 0    53538
# 1     1270
# Name: awards_won?, dtype: int64

# %%
test=pd.read_csv('C:/Users/hp/Desktop/Python Courses/Employee project/test.csv')
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
test['previous_year_rating'].fillna(test['previous_year_rating'].mean(), inplace=True)
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
test['previous_year_rating'].max()
# Out:
# 5.0

# %%
pd.cut(test['previous_year_rating'], bins=['0.0','2.9','5.0'], labels=['0','1'])
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 23485    1
# 23486    1
# 23487    1
# 23488    1
# 23489    1
# Name: previous_year_rating, Length: 23490, dtype: category
# Categories (2, object): ['0' < '1']

# %%
data3=pd.DataFrame(pd.cut(test['previous_year_rating'], bins=['0.0','2.9','5.0'], labels=['0','1']))
test.update(data3, overwrite=True)
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
pd.cut(test['avg_training_score'], bins=['0','59','99'], labels=['0','1'])
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 23485    1
# 23486    1
# 23487    0
# 23488    1
# 23489    1
# Name: avg_training_score, Length: 23490, dtype: category
# Categories (2, object): ['0' < '1']

# %%
data4=pd.DataFrame(pd.cut(test['avg_training_score'], bins=['0','59','99'], labels=['0','1']))
test.update(data4, overwrite=True)
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
test['is_promoted']='0'
test
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
feature_cols=['previous_year_rating','KPIs_met >80%','awards_won?','avg_training_score']
x_train=train[feature_cols]
y_train=train.is_promoted
x_test=test[feature_cols]
y_test=test.is_promoted
clf=DecisionTreeClassifier()
clf=clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
pred=pd.DataFrame(y_pred)
pred.value_counts()
# Out:
# 0    23384
# 1      106
# dtype: int64

# %%
pred=pred.rename(columns={0:'is_promoted'})
pred
# Out:
#        is_promoted
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 23485            0
# 23486            0
# 23487            0
# 23488            0
# 23489            0
#
# [23490 rows x 1 columns]

# %%
test.update(pred, overwrite=True)
test=test.groupby('is_promoted')
print('Employees Promoted')
test.get_group(1)
# Out:
# Employees Promoted
#        employee_id   department     region         education gender  \
# 124          55735   Technology  region_31  Master's & above      m
# 350          39224   Technology  region_27        Bachelor's      m
# 548          16924   Operations  region_13  Master's & above      f
# 689          19098    Analytics  region_15        Bachelor's      m
# 805          57352   Operations  region_22  Master's & above      m
# ...            ...          ...        ...               ...    ...
# 21421          285   Operations   region_5  Master's & above      m
# 21491        31396      Finance   region_7        Bachelor's      f
# 21947        26132   Technology   region_7   Below Secondary      f
# 22797        28761  Procurement   region_7  Master's & above      m
# 23133        23742  Procurement  region_20  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
test=test.get_group(1)
print('Statistical Representation of Promoted Employees in each department:')
test['department'].value_counts().plot.bar()
# Out:
# Statistical Representation of Promoted Employees in each department:
# <AxesSubplot:>

# %%
print('Statistical Representation of Promoted Employees by Recruitment channel:')
test['recruitment_channel'].value_counts().plot.bar()
# Out:
# Statistical Representation of Promoted Employees by Recruitment channel:
# <AxesSubplot:>

# %%
print('Statistical Representation of Promoted Employees by education:')
test['education'].value_counts().plot.bar()
# Out:
# Statistical Representation of Promoted Employees by education:
# <AxesSubplot:>

# %%
print('Statistical Representation of Promoted Employees by Gender:')
test['gender'].value_counts().plot.bar()
# Out:
# Statistical Representation of Promoted Employees by Gender:
# <AxesSubplot:>

# %%
test=test.groupby('is_promoted')
print('Employees Promoted')
test.get_group(1)
result=test.get_group(1)
result.to_csv('result.csv')
# Out:
# Employees Promoted
